# %% [markdown]
# <a href="https://colab.research.google.com/github/rganesh203/Python-Core-Fundamentals/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#enumerate

# %%
# ?enumerate

# %%
list1=[1,2,3,4]

# %%
d=dict(enumerate(list1))

# %%
d.

# %%
d.keys()

# %%
d.values()

# %%
d[0]

# %%
#dictionary comprehension
syntax:
={key:value for (key,value) in iterable if condition}

# %%
list1

# %%
dic={}
for i in list1:
    if i%2==0:
        dic[i]=i*2
print(dic)

# %%
d={i:i*2 for i in list1 if i%2==0}

# %%
d

# %%
a=["a","b"]
b=[1,2]

# %%
dict1={}
for key, value in zip(a,b):
    dict1[key]=value
print(dict1)

# %%
d1={key:value for (key, value) in zip(a,b)}

# %%
d1

# %%
#generator comprehension
syntax:
(expression for var in list if condition)

# %%
list1

# %%
g=(i*2 for i in list1)

# %%
g

# %%
type(g)

# %%
for j in g:
    print(j)

# %%
mylist = iter(["apple", "banana", "cherry"])
x = next(mylist)
print(x)
x = next(mylist)
print(x)
x = next(mylist)
print(x)

# %%
#generator
#we use yield keyword rather than

# %%
"""def function_name():
    #statements
    yield statements"""

# %%
def simplefun():
    yield 1
    yield 2
    yield 3
#driver code
for i in simplefun():
    print(i)

# %%
def simplefun():
    yield 1
    yield 2
    yield 3
#driver code
a=simplefun()
print(next(a))
print(next(a))
print(next(a))

# %%
def fun1(a):
    print("a",a,id(a))
    a=a+1#local variable
    print("inside of after", a, id(a))
a=10#global variable
fun1(a)
print("after",a,id(a))

# %%
b=10
def fun():
    b=b+1
    print(b)
fun()

# %%
#b=10
def fun():
    global b
    b=b+1
    print(b)
b=10
fun()
print("after calling",b)

# %%
def fun():
    #global b
    c=20
    c=c+10
    print(c)
c=10
fun()
print("after calling",c)

# %%
# i a m creating file which is module simply call it as .py
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
#save it in name module name

# %%
from module_name import sub

# %%
#new file
import module_name
print(module_name.add(2,3))

# %%
import numpy as np

# %%
np.array([1,2,3,4])

# %%
from numpy import array

# %%
def sum(a,b):
    return a+b
if __name__=="__main__":
    print(sum(12,10))

# %%
#map,N----->N
#filter, splitting dataN-------->N-1
#reduce,single output, N---->1

# %%
l=[1,2,3,4]
multiply=list(map(lambda x:x*2,l))

# %%
print(multiply)

# %%
l=[1,2,3,4]
filting =list(filter(lambda x:x%2==0,l))

# %%
print(filting)

# %%
import functools
filting =functools.reduce(lambda x,y:x+y,l)

# %%
print(filting)

# %%
l

# %%
def fun(a):
    return a*2
list2=map(fun,l)
print(list(list2))

# %%
def fun(a):
    for i in l:
        if i%2==0:
            print(i)
list2=filter(fun,l)
print(list(list2))

# %%
[2,4]
